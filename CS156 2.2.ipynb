# %%
import numpy as np
import matplotlib.pyplot as plt

import pandas as pd
from datetime import datetime

data = pd.read_csv('facebook_train.csv')

# %%
print(data)
# Out:
#      total_followers    type  category  month  weekday  hour  paid  comment  \
# 0             124050   Photo         3      6        4    17     1        3
# 1             132556   Photo         2      8        3    24     0       11
# 2              92786   Photo         2      2        6    17     1        2
# 3             135632   Photo         1      9        2     1     0        2
# 4             139540    Link         1     12        3    17     1        7
# 5             138969   Photo         3     12        5    17     1        3
# 6             124025   Photo         3      6        3    18     0       10
# 7             131431  Status         2      7        6    20     1        7
# 8             137820   Photo         1     11        7    16     1       21
# 9             137553  Status         2     11        4    17     0        2
# 10            136532   Photo         1     11        4     2     0        2
# 11            115484   Photo         1      4        5    16     0        5
# 12            138660   Photo         2     12        6    17     0       22
# 13            117962   Photo         3      5        4     3     1        3
# 14            124912   Photo         1      6        2     3     1       10
# 15             93892   Photo         3      2        5     3     0      180
# 16            106259   Photo         1      4        7    18     1        4
# 17            119910   Photo         3      5        7    19     0        1
# 18            131498   Video         1      7        7     1     1       21
# 19            106413   Photo         3      4        5    17     0        1
# 20            137609   Photo         3     10        5     1     0       10
# 21            133244   Photo         3      8        3    17     1        7
# 22            100220   Photo         1      3        4     2     0        0
# 23            134251   Photo         1     10        1    24     0        8
# 24            100558   Photo         1      3        4     7     0        5
# 25            123938   Photo         2      6        1    19     1       22
# 26            136552  Status         2     10        2    17     0        0
# 27            108749   Photo         1      4        3     3     0        1
# 28            139573   Photo         1     11        6    24     1       11
# 29            135324   Photo         3      9        6    23     0        3
# ..               ...     ...       ...    ...      ...   ...   ...      ...
# 367           125169   Photo         3      6        6     3     0        3
# 368           133271   Photo         3      8        1    17     1        4
# 369           107833   Photo         2      4        2    17     0        8
# 370           104504   Photo         1      3        1     4     1        3
# 371           128306   Photo         1      7        3    17     0        2
# 372           124235   Photo         2      6        7    17     0        1
# 373           122780   Photo         3      6        5    17     1        2
# 374           135460   Photo         2      9        5    17     1        1
# 375           125483   Photo         1      6        4    18     0        0
# 376           139671   Photo         3     12        6    23     0        4
# 377           135341   Photo         3     10        4    24     0        0
# 378           133420   Photo         1      8        5     2     1        0
# 379           138895   Photo         1     11        1    17     1        5
# 380            84566   Photo         3      1        3     1     0        1
# 381           138879   Photo         3     12        3    24     0        3
# 382           117725    Link         1      5        5    16     0        3
# 383           121928   Photo         3      5        7     2     0       24
# 384           138870   Photo         2     12        2    17     0        5
# 385           137918    Link         1     10        2    24     0        0
# 386           129361   Photo         3      7        4    17     0        8
# 387           137303   Video         1     11        2    17     1       20
# 388           138696  Status         2     12        3     1     0        8
# 389            98605   Photo         3      3        1     3     0       11
# 390           135926   Photo         2      9        2    16     0        8
# 391           132721   Photo         1      8        1    23     1        0
# 392           138114  Status         2     12        2     1     0       12
# 393           127937  Status         2      6        3    18     0        4
# 394           135656   Video         1      9        6    24     0        7
# 395           124663   Photo         3      6        3    16     1        1
# 396            93096   Photo         1      2        3     3     1        6
#
#      like  share
# 0      77     16
# 1     313     50
# 2     145     39
# 3     299     49
# 4     229     21
# 5     284     31
# 6     240     28
# 7      16      1
# 8     490     90
# 9      96     15
# 10     36      8
# 11     48     10
# 12    399     58
# 13    189     23
# 14    243     32
# 15   1826    208
# 16    153     19
# 17    131     31
# 18    372     91
# 19     63     30
# 20    221     37
# 21    114      3
# 22      4      0
# 23    195     29
# 24    247     16
# 25    199     60
# 26    152     31
# 27     74     27
# 28    217     15
# 29    234     32
# ..    ...    ...
# 367   163     20
# 368   538     37
# 369   167     28
# 370   210     33
# 371    82     28
# 372    89     27
# 373    67      7
# 374   106     16
# 375    16      1
# 376   114     27
# 377    98     17
# 378    47      3
# 379   167     19
# 380    98     35
# 381   143     31
# 382    54     17
# 383   236     38
# 384   167     12
# 385    38     18
# 386   631     70
# 387   529     97
# 388   255     48
# 389   803    116
# 390   302     50
# 391    34      2
# 392   498     87
# 393    85     20
# 394   397    143
# 395    87     18
# 396   296     32
#
# [397 rows x 10 columns]

# %%
train_data = []
length = len(data.type)

for i in range(length):
    initial = []
    initial.append(data.total_followers[i])
    type_ = data.type[i]
    if type_ == 'Photo':
        initial.append(0)
    elif type == 'Link':
        initial.append(1)
    else:
        initial.append(2)
    initial.append(data.category[i])
    initial.append(data.month[i])
    initial.append(data.weekday[i])
    initial.append(data.paid[i])
    train_data.append(initial)

# %%
target_data_comment = np.array(data.comment).reshape(-1,1)
target_data_like = np.array(data.like).reshape(-1,1)
target_data_share = np.array(data.share).reshape(-1,1)

# %%
from sklearn import linear_model
reg_comment = linear_model.LinearRegression()
reg_like = linear_model.LinearRegression()
reg_share = linear_model.LinearRegression()

reg_comment.fit(train_data,target_data_comment)
reg_like.fit(train_data,target_data_like)
reg_share.fit(train_data,target_data_share)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
comment_prediction = reg_comment.predict(train_data)
like_prediction = reg_like.predict(train_data)
share_prediction = reg_share.predict(train_data)

# %%
plt.figure(figsize =(12,6))
plt.plot(range(length),comment_prediction,label='Comments Prediction')
plt.plot(range(length),data.comment,label='Actual Number of Comments')
plt.legend()
plt.show()
print(reg_comment.coef_)
# Out:
# [[ 4.45904824e-04 -3.63258851e-01  4.28548811e-01 -2.03218153e+00
#    8.41036233e-01  4.51085537e+00]]

# %%
plt.figure(figsize =(12,6))
plt.plot(range(length),like_prediction,label='Likes Prediction')
plt.plot(range(length),data.like,label='Actual Number of Likes')
plt.legend()
plt.show()
print(reg_like.coef_)
# Out:
# [[ 4.11884015e-03 -1.69304287e+01  5.92393213e+01 -1.39893664e+01
#    7.42381125e+00  1.13645994e+02]]

# %%
plt.figure(figsize =(12,6))
plt.plot(range(length),share_prediction,label='Share Prediction')
plt.plot(range(length),data.share,label='Actual Number of Shares')
plt.legend()
plt.show()
print(reg_share.coef_)
# Out:
# [[ 4.65567361e-04  2.62432452e+00  9.19336161e+00 -2.31028691e+00
#    1.72708136e+00  1.04473303e+01]]

# %% [markdown]
# # Question 2

# %%
casualty_data = pd.read_csv('casualty_train.csv')
print(casualty_data)
# Out:
#        casualty_class  gender      age  severe pedestrian_location  \
# 0           passenger  female       33   False                 NaN
# 1           passenger  female       20   False                 NaN
# 2           passenger    male       52   False                 NaN
# 3           passenger  female       17   False                 NaN
# 4           passenger  female       20   False                 NaN
# 5          pedestrian  female       40    True             In road
# 6           passenger  female       40   False                 NaN
# 7           passenger  female       23   False                 NaN
# 8              driver  female       45   False                 NaN
# 9          pedestrian    male        8   False   Close to Crossing
# 10             driver  female        8   False                 NaN
# 11          passenger  female        7   False                 NaN
# 12             driver    male       33   False                 NaN
# 13             driver  female  Unknown   False                 NaN
# 14          passenger  female       43   False                 NaN
# 15         pedestrian    male       34   False     Not on Crossing
# 16          passenger  female       32   False                 NaN
# 17          passenger  female       31   False                 NaN
# 18             driver  female       29   False                 NaN
# 19          passenger  female  Unknown   False                 NaN
# 20          passenger  female       45    True                 NaN
# 21          passenger  female       50   False                 NaN
# 22             driver    male        4   False                 NaN
# 23             driver  female       12   False                 NaN
# 24          passenger    male       25   False                 NaN
# 25          passenger  female       27   False                 NaN
# 26          passenger  female  Unknown   False                 NaN
# 27          passenger    male       29   False                 NaN
# 28          passenger    male        8   False                 NaN
# 29          passenger  female       50   False                 NaN
# ...               ...     ...      ...     ...                 ...
# 232805      passenger  female       37   False                 NaN
# 232806     pedestrian  female       45   False     Not on Crossing
# 232807      passenger  female       41   False                 NaN
# 232808      passenger  female       30   False                 NaN
# 232809      passenger  female       42    True                 NaN
# 232810      passenger  female       15   False                 NaN
# 232811      passenger  female       14   False                 NaN
# 232812         driver  female  Unknown   False                 NaN
# 232813         driver    male        0   False                 NaN
# 232814      passenger  female       28   False                 NaN
# 232815      passenger    male       20   False                 NaN
# 232816         driver    male       22   False                 NaN
# 232817      passenger  female       37   False                 NaN
# 232818      passenger  female       28   False                 NaN
# 232819         driver  female       54   False                 NaN
# 232820      passenger  female       34   False                 NaN
# 232821     pedestrian  female       10   False     Not on Crossing
# 232822         driver  female        1   False                 NaN
# 232823     pedestrian  female  Unknown   False             In road
# 232824      passenger  female       46   False                 NaN
# 232825      passenger    male       38   False                 NaN
# 232826      passenger  female       15   False                 NaN
# 232827      passenger  female       25   False                 NaN
# 232828     pedestrian  female        3   False     Not on Crossing
# 232829      passenger  female  Unknown   False                 NaN
# 232830      passenger  female       40   False                 NaN
# 232831      passenger  female       41   False                 NaN
# 232832     pedestrian  female       45   False   Close to Crossing
# 232833     pedestrian    male       10    True   Close to Crossing
# 232834      passenger  female       37   False                 NaN
#
#        pedestrian_movement      travel  year
# 0                      NaN   motorbike  2007
# 1                      NaN         car  2005
# 2                      NaN         car  2006
# 3                      NaN  pedestrian  2012
# 4                      NaN   motorbike  2010
# 5       In Rd Not Crossing     bicycle  2008
# 6                      NaN   motorbike  2005
# 7                      NaN        taxi  2007
# 8                      NaN         car  2006
# 9           Drivers N/Side     bicycle  2010
# 10                     NaN         car  2006
# 11                     NaN  pedestrian  2005
# 12                     NaN         car  2010
# 13                     NaN         car  2007
# 14                     NaN  pedestrian  2012
# 15          Drivers N/Side     bicycle  2012
# 16                     NaN   motorbike  2008
# 17                     NaN   motorbike  2012
# 18                     NaN         car  2008
# 19                     NaN         car  2005
# 20                     NaN  pedestrian  2011
# 21                     NaN        taxi  2011
# 22                     NaN         bus  2007
# 23                     NaN         car  2009
# 24                     NaN   motorbike  2006
# 25                     NaN   motorbike  2010
# 26                     NaN  pedestrian  2011
# 27                     NaN         car  2008
# 28                     NaN  pedestrian  2005
# 29                     NaN         car  2010
# ...                    ...         ...   ...
# 232805                 NaN         car  2006
# 232806  Drivers N/Side Msk     bicycle  2013
# 232807                 NaN         car  2011
# 232808                 NaN         car  2007
# 232809                 NaN         car  2006
# 232810                 NaN  pedestrian  2006
# 232811                 NaN  pedestrian  2010
# 232812                 NaN         car  2014
# 232813                 NaN         car  2010
# 232814                 NaN   motorbike  2013
# 232815                 NaN         car  2010
# 232816                 NaN         car  2014
# 232817                 NaN         car  2014
# 232818                 NaN   motorbike  2010
# 232819                 NaN         car  2006
# 232820                 NaN         car  2014
# 232821  Drivers N/Side Msk     bicycle  2006
# 232822                 NaN         car  2005
# 232823    Unknown Or Other     bicycle  2012
# 232824                 NaN         car  2010
# 232825                 NaN  pedestrian  2013
# 232826                 NaN  pedestrian  2011
# 232827                 NaN         car  2006
# 232828      Drivers N/Side     bicycle  2007
# 232829                 NaN         car  2006
# 232830                 NaN         car  2014
# 232831                 NaN  pedestrian  2013
# 232832      Drivers N/Side     bicycle  2010
# 232833  Drivers N/Side Msk     bicycle  2009
# 232834                 NaN         car  2014
#
# [232835 rows x 8 columns]

# %%
age = casualty_data.age
year = casualty_data.year
indexes = []
for i in range(len(age)):
    if age[i] == 'Unknown':
        indexes.append(i)

for i in range(len(age)):
    if year[i] == 'Unknown':
        indexes.append(i)

casualty_data.drop(indexes)
# Out:
#        casualty_class  gender age  severe pedestrian_location  \
# 0           passenger  female  33   False                 NaN
# 1           passenger  female  20   False                 NaN
# 2           passenger    male  52   False                 NaN
# 3           passenger  female  17   False                 NaN
# 4           passenger  female  20   False                 NaN
# 5          pedestrian  female  40    True             In road
# 6           passenger  female  40   False                 NaN
# 7           passenger  female  23   False                 NaN
# 8              driver  female  45   False                 NaN
# 9          pedestrian    male   8   False   Close to Crossing
# 10             driver  female   8   False                 NaN
# 11          passenger  female   7   False                 NaN
# 12             driver    male  33   False                 NaN
# 14          passenger  female  43   False                 NaN
# 15         pedestrian    male  34   False     Not on Crossing
# 16          passenger  female  32   False                 NaN
# 17          passenger  female  31   False                 NaN
# 18             driver  female  29   False                 NaN
# 20          passenger  female  45    True                 NaN
# 21          passenger  female  50   False                 NaN
# 22             driver    male   4   False                 NaN
# 23             driver  female  12   False                 NaN
# 24          passenger    male  25   False                 NaN
# 25          passenger  female  27   False                 NaN
# 27          passenger    male  29   False                 NaN
# 28          passenger    male   8   False                 NaN
# 29          passenger  female  50   False                 NaN
# 30         pedestrian  female   8   False             Unknown
# 31             driver  female  38   False                 NaN
# 33             driver  female  39   False                 NaN
# ...               ...     ...  ..     ...                 ...
# 232802      passenger  female  42   False                 NaN
# 232803     pedestrian    male  42    True     Not on Crossing
# 232804     pedestrian    male  27    True   Close to Crossing
# 232805      passenger  female  37   False                 NaN
# 232806     pedestrian  female  45   False     Not on Crossing
# 232807      passenger  female  41   False                 NaN
# 232808      passenger  female  30   False                 NaN
# 232809      passenger  female  42    True                 NaN
# 232810      passenger  female  15   False                 NaN
# 232811      passenger  female  14   False                 NaN
# 232813         driver    male   0   False                 NaN
# 232814      passenger  female  28   False                 NaN
# 232815      passenger    male  20   False                 NaN
# 232816         driver    male  22   False                 NaN
# 232817      passenger  female  37   False                 NaN
# 232818      passenger  female  28   False                 NaN
# 232819         driver  female  54   False                 NaN
# 232820      passenger  female  34   False                 NaN
# 232821     pedestrian  female  10   False     Not on Crossing
# 232822         driver  female   1   False                 NaN
# 232824      passenger  female  46   False                 NaN
# 232825      passenger    male  38   False                 NaN
# 232826      passenger  female  15   False                 NaN
# 232827      passenger  female  25   False                 NaN
# 232828     pedestrian  female   3   False     Not on Crossing
# 232830      passenger  female  40   False                 NaN
# 232831      passenger  female  41   False                 NaN
# 232832     pedestrian  female  45   False   Close to Crossing
# 232833     pedestrian    male  10    True   Close to Crossing
# 232834      passenger  female  37   False                 NaN
#
#        pedestrian_movement      travel  year
# 0                      NaN   motorbike  2007
# 1                      NaN         car  2005
# 2                      NaN         car  2006
# 3                      NaN  pedestrian  2012
# 4                      NaN   motorbike  2010
# 5       In Rd Not Crossing     bicycle  2008
# 6                      NaN   motorbike  2005
# 7                      NaN        taxi  2007
# 8                      NaN         car  2006
# 9           Drivers N/Side     bicycle  2010
# 10                     NaN         car  2006
# 11                     NaN  pedestrian  2005
# 12                     NaN         car  2010
# 14                     NaN  pedestrian  2012
# 15          Drivers N/Side     bicycle  2012
# 16                     NaN   motorbike  2008
# 17                     NaN   motorbike  2012
# 18                     NaN         car  2008
# 20                     NaN  pedestrian  2011
# 21                     NaN        taxi  2011
# 22                     NaN         bus  2007
# 23                     NaN         car  2009
# 24                     NaN   motorbike  2006
# 25                     NaN   motorbike  2010
# 27                     NaN         car  2008
# 28                     NaN  pedestrian  2005
# 29                     NaN         car  2010
# 30        Unknown Or Other     bicycle  2005
# 31                     NaN         car  2008
# 33                     NaN         car  2005
# ...                    ...         ...   ...
# 232802                 NaN  pedestrian  2007
# 232803      Drivers N/Side     bicycle  2010
# 232804      Drivers N/Side     bicycle  2012
# 232805                 NaN         car  2006
# 232806  Drivers N/Side Msk     bicycle  2013
# 232807                 NaN         car  2011
# 232808                 NaN         car  2007
# 232809                 NaN         car  2006
# 232810                 NaN  pedestrian  2006
# 232811                 NaN  pedestrian  2010
# 232813                 NaN         car  2010
# 232814                 NaN   motorbike  2013
# 232815                 NaN         car  2010
# 232816                 NaN         car  2014
# 232817                 NaN         car  2014
# 232818                 NaN   motorbike  2010
# 232819                 NaN         car  2006
# 232820                 NaN         car  2014
# 232821  Drivers N/Side Msk     bicycle  2006
# 232822                 NaN         car  2005
# 232824                 NaN         car  2010
# 232825                 NaN  pedestrian  2013
# 232826                 NaN  pedestrian  2011
# 232827                 NaN         car  2006
# 232828      Drivers N/Side     bicycle  2007
# 232830                 NaN         car  2014
# 232831                 NaN  pedestrian  2013
# 232832      Drivers N/Side     bicycle  2010
# 232833  Drivers N/Side Msk     bicycle  2009
# 232834                 NaN         car  2014
#
# [216610 rows x 8 columns]

# %%
from sklearn.preprocessing import LabelEncoder

le1 = LabelEncoder()
le1.fit(casualty_data.casualty_class)
casualty_class = le1.transform(casualty_data.casualty_class)

# %%
le2 = LabelEncoder()
le2.fit(casualty_data.gender)
gender = le2.transform(casualty_data.gender)

le5 = LabelEncoder()
le5.fit(casualty_data.travel)
travel = le5.transform(casualty_data.travel)

le6 = LabelEncoder()
le6.fit(casualty_data.severe)
severe = le6.transform(casualty_data.severe)

# %%
train1 = []

for i in range(len(gender)):
    initial = []
    initial.append(casualty_class[i])
    initial.append(gender[i])
    initial.append(casualty_data.age[i])
    initial.append(travel[i])
    initial.append(casualty_data.year[i])
    train1.append(initial)

# %%
target1 = np.array(severe).reshape(-1,1)

# %%
reg = linear_model.LinearRegression()
reg.fit(train1,target1)
prediction = reg.predict(train1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-89-ebab458b11da> in <module>()
#       1 reg = linear_model.LinearRegression()
# ----> 2 reg.fit(train1,target1)
#       3 prediction = reg.predict(train1)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/base.py in fit(self, X, y, sample_weight)
#     487         X, y, X_offset, y_offset, X_scale = self._preprocess_data(
#     488             X, y, fit_intercept=self.fit_intercept, normalize=self.normalize,
# --> 489             copy=self.copy_X, sample_weight=sample_weight)
#     490
#     491         if sample_weight is not None:
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/base.py in _preprocess_data(X, y, fit_intercept, normalize, copy, sample_weight, return_mean)
#     166
#     167     X = check_array(X, copy=copy, accept_sparse=['csr', 'csc'],
# --> 168                     dtype=FLOAT_DTYPES)
#     169     y = np.asarray(y, dtype=X.dtype)
#     170
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     431                                       force_all_finite)
#     432     else:
# --> 433         array = np.array(array, dtype=dtype, order=order, copy=copy)
#     434
#     435         if ensure_2d:
#
# ValueError: could not convert string to float: 'Unknown'
